# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import json
from json import JSONEncoder

# %%
baseUrl = "https://www.vlr.gg"

class HeadToHeadData():
    def __init__(self):
        self.Date = ""
        self.Team1Score = 0
        self.Team2Score = 0

class PastMatchesData():
    def __init__(self):
        self.Team2 = ""
        self.OurTeamScore = 0
        self.Team2Score = 0
        self.Date = ""
        
class PlayerData():
    def __init__(self):
        self.Name = ""
        self.Team = ""
        self.ACS = 0
        self.Kills = 0
        self.Deaths = 0
        self.Assists = 0
        self.KAST = 0
        self.ADR = 0
        self.HeadshotPercent = 0
        self.FirstKills = 0
        self.FirstDeaths = 0

class MapData():
    def __init__(self):
        self.ListOfPlayerDataTeam1 = []
        self.ListOfPlayerDataTeam2 = []
        self.ListOfRounds = []
        self.MapName = "" #All if it is overall stats
        self.MapNumber = 0 #0 if overall stats
        self.Team1Score = 0
        self.Team1Attack = 0
        self.Team2Score = 0
        self.Team2Attack = 0
        self.Pick = ""
        
class MatchData():
    def __init__(self):
        self.Date = ""
        self.Team1 = ""
        self.Team1Score = 0
        self.Team2 = ""
        self.Team2Score = 0
        
        self.ListOfMapData = []
        
        self.ListOfHeadToHead = []
        self.Team1PastMatches = []
        self.Team2PastMatches = []
        
class EmployeeEncoder(JSONEncoder):
        def default(self, o):
            return o.__dict__

# %%
response = requests.get("https://www.vlr.gg/event/matches/1015/valorant-champions-2022/?series_id=all&group=completed")

# %%
response.status_code

########## Check condition if the response is 200 
########## then only proceed
# Out:
# 200

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en"> \n\t<head>\n\t\t<title>\n\t\t\tValorant Champions 2022: Schedule and Results | Valorant Event | VLR.gg\t\t</title>\n\n\t\t\t\t\t<meta name="description" content="Valorant Champions 2022 results, upcoming matches, and VODs">\n\t\t\t\t<meta charset="utf-8">\n\n\t\t<meta property="og:title" content="Valorant Champions 2022: Schedule and Results | Valorant Event | VLR.gg">\n\t\t<meta property="og:site_name" content="VLR.gg">\n\n\t\t\t\t\t<meta property="og:description" content="Valorant Champions 2022 results, upcoming matches, and VODs">\n\t\t\n\t\t\t\t\t<meta property="og:image" content="https://owcdn.net/img/63067806d167d.png">\n\t\t\n\t\t\t\t\t<meta name="twitter:card" content="summary">\n\t\t\n\t\t\t\t\t<meta name="twitter:site" content="@vlrdotgg">\n\t\t\n\t\t<meta name="twitter:title" content="Valorant Champions 2022: Schedule and Results | Valorant Event | VLR.gg">\n\n\t\t\t\t\t<meta name="twitter:description" content="Valorant Champions 2022 results, upcoming matches, and VODs">\n\t\t\n\t\t\t\t\t<meta name="twitter:image" content="https://owcdn.net/img/63067806d167d.png">\n\t\t\t\t\n\t\t<meta name="theme-color" content="#000">\n\t\t<meta name="msapplication-navbutton-color" content="#000">\n\t\t<meta name="apple-mobile-web-app-status-bar-style" content="#000">\n\n\t\t<link href=\'https://fonts.googleapis.com/css?family=Roboto:400,400italic,300,700,500\' rel=\'stylesheet\' type=\'text/css\'>\n\t\t<link rel="stylesheet" href="/css/base/main.css?v=22" type="text/css">\n\n\t\t\t\t\t\n\t\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0">\n\t\t\t<link rel="stylesheet" href="/css/base/r.css?v=26" type="text/css">\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\t<link rel="stylesheet" href="/css/base/pages/event.css?v=73" type="text/css">\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\t<link rel="stylesheet" href="/css/base/pages/r/event.css?v=12" type="text/css">\n\t\t\t\t\t\t\n\t\t\n\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\n\t\t\t\t\t<link rel="icon" type="image/png" href="/img/vlr/logo_lt.png">\n\t\t\n\t\t\n\t\t\t\t\t<link rel="canonical" href="https://www.vlr.gg/event/1015/valorant-champions-2022">\n\t\t\n\t\t<script async src="https://www.googletagmanager.com/gtag/js?id=UA-26950080-6"></script>\n\t\t<script>\n\t\t\twindow.dataLayer = window.dataLayer || [];\n\t\t\tfunction gtag(){dataLayer.push(arguments);}\n\t\t\tgtag(\'js\', new Date());\n\n\t\t\tgtag(\'config\', \'UA-26950080-6\');\n\t\t</script>\n\n\t\t<script type="text/javascript">\nwindow[\'nitroAds\'] = window[\'nitroAds\'] || { createAd: function () { window.nitroAds.queue.push(["createAd", arguments]) }, queue: [] };\n</script>\n<script async src="https://s.nitropay.com/ads-823.js"></script>\t</head>\n\t<body data-ctrl="event" class=""><header class="header">\n\t<nav class="header-inner">\n\t\t<div class="header-shadow"></div>\n\t\t<div class="header-div mod-first"></div>\n\t\t<a href="/" class="header-logo">\n\t\t\t\n\t\t\t\t\t\t\t<img class="header-logo-logo" src="/img/vlr/logo_header.png" style="height: 36px;">\n\t\t\t\t\t</a>\n\t\t<div class="header-search">\n\t\t\t<form action="/search/" method="get">\n\t\t\t\t<input type="search" name="q" spellcheck=false autocomplete=off placeholder="Search...">\n\t\t\t</form>\n\t\t</div>\n\n\t\t<div class="header-div mod-forums"></div>\n\t\t<a href="/threads" class="header-nav-item mod-forums mod-vlr ">\n\t\t\tForums\n\t\t</a>\n\t\t\n\t\t<div class="header-div mod-matches"></div>\n\t\t<a href="/matches" class="header-nav-item mod-matches mod-vlr ">\n\t\t\tMatches\n\t\t</a>\n\n\t\t<div class="header-div mod-events"></div>\n\t\t<a href="/events" class="header-nav-item mod-events mod-vlr ">\n\t\t\tEvents\n\t\t</a>\n\n\t\t<div class="header-div mod-rankings"></div>\n\n\t\t<a href="/rankings" class="header-nav-item mod-rankings mod-vlr ">\n\t\t\tRankings\n\n\t\t\t\t\t\t\t<span style="background: #da626c; position: absolute; top: 6px; right: 6px; display: inline-block; padding: 2px 3px; border ...

# %%
eventSoup = BeautifulSoup(response.text)

# %%
eventSoup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>
# 			Valorant Champions 2022: Schedule and Results | Valorant Event | VLR.gg		</title>
# <meta content="Valorant Champions 2022 results, upcoming matches, and VODs" name="description"/>
# <meta charset="utf-8"/>
# <meta content="Valorant Champions 2022: Schedule and Results | Valorant Event | VLR.gg" property="og:title"/>
# <meta content="VLR.gg" property="og:site_name"/>
# <meta content="Valorant Champions 2022 results, upcoming matches, and VODs" property="og:description"/>
# <meta content="https://owcdn.net/img/63067806d167d.png" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@vlrdotgg" name="twitter:site"/>
# <meta content="Valorant Champions 2022: Schedule and Results | Valorant Event | VLR.gg" name="twitter:title"/>
# <meta content="Valorant Champions 2022 results, upcoming matches, and VODs" name="twitter:description"/>
# <meta content="https://owcdn.net/img/63067806d167d.png" name="twitter:image"/>
# <meta content="#000" name="theme-color"/>
# <meta content="#000" name="msapplication-navbutton-color"/>
# <meta content="#000" name="apple-mobile-web-app-status-bar-style"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto:400,400italic,300,700,500" rel="stylesheet" type="text/css"/>
# <link href="/css/base/main.css?v=22" rel="stylesheet" type="text/css"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/css/base/r.css?v=26" rel="stylesheet" type="text/css"/>
# <link href="/css/base/pages/event.css?v=73" rel="stylesheet" type="text/css"/>
# <link href="/css/base/pages/r/event.css?v=12" rel="stylesheet" type="text/css"/>
# <link href="/img/vlr/logo_lt.png" rel="icon" type="image/png"/>
# <link href="https://www.vlr.gg/event/1015/valorant-champions-2022" rel="canonical"/>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-26950080-6"></script>
# <script>
# 			window.dataLayer = window.dataLayer || [];
# 			function gtag(){dataLayer.push(arguments);}
# 			gtag('js', new Date());
#
# 			gtag('config', 'UA-26950080-6');
# 		</script>
# <script type="text/javascript">
# window['nitroAds'] = window['nitroAds'] || { createAd: function () { window.nitroAds.queue.push(["createAd", arguments]) }, queue: [] };
# </script>
# <script async="" src="https://s.nitropay.com/ads-823.js"></script> </head>
# <body class="" data-ctrl="event"><header class="header">
# <nav class="header-inner">
# <div class="header-shadow"></div>
# <div class="header-div mod-first"></div>
# <a class="header-logo" href="/">
# <img class="header-logo-logo" src="/img/vlr/logo_header.png" style="height: 36px;"/>
# </a>
# <div class="header-search">
# <form action="/search/" method="get">
# <input autocomplete="off" name="q" placeholder="Search..." spellcheck="false" type="search"/>
# </form>
# </div>
# <div class="header-div mod-forums"></div>
# <a class="header-nav-item mod-forums mod-vlr" href="/threads">
# 			Forums
# 		</a>
# <div class="header-div mod-matches"></div>
# <a class="header-nav-item mod-matches mod-vlr" href="/matches">
# 			Matches
# 		</a>
# <div class="header-div mod-events"></div>
# <a class="header-nav-item mod-events mod-vlr" href="/events">
# 			Events
# 		</a>
# <div class="header-div mod-rankings"></div>
# <a class="header-nav-item mod-rankings mod-vlr" href="/rankings">
# 			Rankings
#
# 							<span style="background: #da626c; position: absolute; top: 6px; right: 6px; display: inline-block; padding: 2px 3px; border-radius: 2px; line-height: 1; height: auto; font-size: 9px; color: #f8f8f8; font-weight: 400;">
# 				 	BETA2
# 				</span>
# </a>
# <div class="header-div mod-stats"></div>
# <a class="header-nav-item mod-stats mod-vlr" href="/stats" style="position: relative;">
# 				Stats
# 			</a>
# <div class="header-div"></div>
# <div class="header-nav-item mod-vlr-spacing" style="width: 150px;"></div>
# <div class="header-div mod-vlr-spacing"></div>
# <div class="header-switch js-dark-switch">
# <div style="text-align: center;">
# <div style="margin-bottom: 4px;">
# <i class="fa fa-moon-o"></i>Night:
# 				</div>
# <span class="on">
# 					ON
# 				</span>
# <span class="off">
# 					OFF
# 				</span>
# </div>
# </div>
# <div class="header-div mod-switch"></div>
# <div class="header-switch js-spoiler-switch mod-active">
# <div style="text-align: center; ">
# <div style="margin-bottom: 4px;">
# <i class="fa fa-exclamation"></i>Spoilers:
# 				</div>
# <span class="on">
# 					ON
# 				</span>
# <span class="off">
# 					HIDDEN
# 				</span>
# </div>
# </div>
# <div class="header-div mod-switch"></div>
# <a class="header-nav-item mod-search mod-solo" href="/search">
# <i class="fa fa-search"></i>
# </a>
# <div class="header-div mod-search">
# </div>
# <a class="header-nav-item mod-login" href="/login">
# 				Log in
# 				<i class="fa fa-sign-in"></i>
# </a>
# <div class="header-nav-item mod-solo mod-dropdown mod-notlogged">
# <i class="fa fa-bars"></i>
# </div>
# <div class="header-div mod-last"></div>
# <div class="header-menu">
# <div class="header-menu-scroll">
# <a class="header-menu-item mod-mobile mod-events" href="/events">Events</a>
# <a class="header-menu-item mod-mobile mod-rankings" href="/rankings">Rankings</a>
# <a class="header-menu-item mod-mobile mod-stats" href="/stats">Stats</a>
# <div class="header-menu-switch js-dark-switch">
# 				Night:
# 				<span class="on">
# 					ON
# 				</span>
# <span class="off">
# 					OFF
# 				</span>
# </div>
# <div class="header-menu-switch js-spoiler-switch mod-active">
# 				Spoilers:
# 				<span class="on">
# 					ON
# 				</span>
# <span class="off">
# 					HIDDEN
# 				</span>
# </div>
# <a class="header-menu-item" href="/login"><i class="fa fa-sign-in"></i> Log in</a>
# </div>
# </div>
# </nav>
# </header>
# <div id="float-right"></div>
# <script type="text/javascript">
# 	window['nitroAds'].createAd('float-right', {
# 	  "refreshLimit": 10,
# 	  "refreshTime": 30,
# 	  "renderVisibleOnly": false,
# 	  "refreshVisibleOnly": true,
# 	  "sizes": [
# 	    [
# 	      "160",
# 	      "600"
# 	    ]
# 	  ],
# 	  "report": {
# 	    "enabled": true,
# 	    "wording": "Report Ad",
# 	    "position": "bottom-left"
# 	  }
# 	});
# 	</script>
# <div id="float-left"></div>
# <script type="text/javascript">
# 		window['nitroAds'].createAd('float-left', {
# 		  "refreshLimit": 10,
# 		  "refreshTime": 30,
# 		  "renderVisibleOnly": false,
# 		  "refreshVisibleOnly": true,
# 		  "sizes": [
# 		    [
# 		      "160",
# 		      "600"
# 		    ]
# 		  ],
# 		  "report": {
# 		    "enabled": true,
# 		    "wording": "Report Ad",
# 		    "position": "bottom-left"
# 		  }
# 		});
# 	</script>
# <div id="wrapper">
# <div class="col-container">
# <div class="col mod-1">
# <div class="wf-card mod-event mod-header mod-full" style="z-index: 3;">
# <div class="event-header">
# <div class="wf-avatar event-header-thumb">
# <div>
# <img alt="Valorant Champions 2022" src="//owcdn.net/img/63067806d167d.png"/>
# </div>
# </div>
# <div class="event-desc">
# <div class="event-desc-inner">
# <div style="display: flex; align-items: center; margin-bottom: 2px;">
# <i class="fa fa-tag" style="font-size: 14px; margin-right: 5px;"></i>
# <a href="/vct">Valorant Champions Tour 2022</a>
# </div>
# <h1 class="wf-title" style="display: inline;">
# 					Valorant Champions 2022				</h1>
# <h2 class="event-desc-subtitle">
# 					The final event of the Valorant Champions Tour, Riot's 2022 tournament circuit				</h2>
# <div class="event-desc-items">
# <div class="event-desc-item">
# <div class="ge-text-light event-desc-item-label">
# 							Dates
# 						</div>
# <div class="event-desc-item-value">
# 							Aug 31, 2022 - Sep 19, 2022						</div>
# </div>
# <div class="event-desc-item">
# <div class="ge-text-light event-desc-item-label">
# 							Prize pool
# 						</div>
# <div class="event-desc-item-value">
# 							$1,000,000 USD													</div>
# </div>
# <div class="event-desc-item mod-last">
# <div class="ge-text-light event-desc-item-label">
# 															Location
# 													</div>
# <div class="event-desc-item-value" style="margin-top: -2px;">
# <i class="flag mod-tr" style="vertical-align: -4px; margin-right: 4px;"></i>
# 							İstanbul, Türkiye						</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="wf-nav" style="z-index: 3;">
# <a class="wf-nav-item mod-first mod-hassubnav" href="/event/1015/valorant-champions-2022">
# <div class="wf-nav-item-title">
# 				Overview
# 			</div>
# </a>
# <!--
# 		<a class="wf-nav-item ">
# 			<div class="wf-nav-item-title">
# 				Teams
# 			</div>
# 		</a>
# 		-->
# <a class="wf-nav-item mod-active" href="/event/matches/1015/valorant-champions-2022">
# <div class="wf-nav-item-title">
# 				Matches (34)
# 			</div>
# </a>
# <a class="wf-nav-item mod-hassubnav" href="/event/pickem/1015/valorant-champions-2022">
# <div class="wf-nav-item-title">
# 					Pick'em
# 				</div>
# </a>
# <a class="wf-nav-item" href="/event/stats/1015/valorant-champions-2022">
# <div class="wf-nav-item-title">
# 					Stats
# 				</div>
# </a>
# <a class="wf-nav-item" href="/event/agents/1015/valorant-champions-2022">
# <div class="wf-nav-item-title">
# 					Agents
# 				</div>
# </a>
# <a class="wf-nav-item" href="/event/news/1015/valorant-champions-2022">
# <div class="wf-nav-item-title">
# 					News (37)
# 				</div>
# </a>
# </div>
# </div><style>
# 	.tl {
# 		height: 24px; width: 24px;
# 		display: block;
# 		margin: 0;
# 		//margin-right: 15px;
# 	}
# 		.tl.mod-right {
# 			margin: 0;
# 			//margin-left: 15px;
# 		}
# 	.tn {
# 		width: 160px;
# 		position: relative;
# 	}
# 		.tn:before {
# 			content: '';
# 			position: absolute;
# 			bottom: -4px;
# 			right: -4px;
# 			background: #fafafa;
# 			width: 8px; height: 8px;
# 			transform: rotate(45deg);
# 		}
# 		.tn:after {
# 			//content: '';
# 			position: absolute;
# 			top: -4px;
# 			right: -4px;
# 			background: #fafafa;
# 			width: 8px; height: 8px;
# 			transform: rotate(45deg);
# 		}
# 		.tn.mod-right:before {
# 			bottom: -4px;
# 			left: -4px;
# 		}
# 		.tn.mod-right:after {
# 			top: -4px;
# 			left: -4px;
# 		}
# 		.tn-n {
# 			//background: #f2f2f2;
# 			padding: 9px;
# 			display: inline-block;
# 			display: flex;
# 			justify-content: flex-end;
# 			align-items: center;
# 		}
# 			.tn-n.mod-right {
# 				justify-content: flex-start;
# 			}
# 			.tn-n.mod-winner {
# 				//background: #c0e2c7;
# 			}
# 	.ms {
# 		background: #eee;
# 		margin: 0 3px;
# 		font-weight: 700;
# 		padding: 5px 6px;
# 		font-size: 11px;
# 		text-decoration: underline;
# 		border-radius: 3px;
# 	}
# </style>
# <div style="display: flex; align-items: center; margin-bottom: 30px;">
# <div style="display: flex; align-items: center;">
# <div class="wf-label" style="padding-bottom: 0; margin-top: -3px; margin-right: 10px;">
# 	 		Stage:
# 	 	</div>
# <span class="btn mod-filter js-dropdown">
# 						All Stages			<span class="arr"></span>
# <span class="wf-dropdown mod-all">
# <a href="/event/matches/1015/valorant-champions-2022/?group=completed&amp;series_id=all">All Stages</a>
# <a href="/event/matches/1015/valorant-champions-2022/?group=completed&amp;series_id=2184">
# 						Playoffs					</a>
# <a href="/event/matches/1015/valorant-champions-2022/?group=completed&amp;series_id=2183">
# 						Group Stage					</a>
# </span>
# </span>
# </div>
# <div style="display: flex; align-items: center;">
# <div class="wf-label" style="padding-bottom: 0; margin-top: -3px; margin-right: 10px;">
# 	 		Status:
# 	 	</div>
# <span class="btn mod-filter js-dropdown">
# 						Completed			<span class="arr"></span>
# <span class="wf-dropdown mod-all">
# <a href="/event/matches/1015/valorant-champions-2022/?series_id=all&amp;group=all">All</a>
# <a href="/event/matches/1015/valorant-champions-2022/?series_id=all&amp;group=upcoming">Upcoming</a>
# <a href="/event/matches/1015/valorant-champions-2022/?series_id=all&amp;group=completed" selected="">Completed</a>
# </span>
# </span>
# </div>
# </div> <div class="wf-label mod-large">
# 			Sat, September 17, 2022
# 							<span class="wf-tag" style="vertical-align: -3px; margin-left: 4px;">Yesterday</span>
# </div>
# <div class="wf-card" style="margin-bottom: 30px;">
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple mod-first" href="/130691/optic-gaming-vs-drx-valorant-champions-2022-lbf">
# <div class="match-item-time">
# 													7:30 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-us"></span>
# 											OpTic Gaming										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					3																			</div>
# </div>
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-kr"></span>
# 											DRX										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">1d 3h</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Lower Final							</div>
# 							Playoffs											</div>
# </a>
# </div>
# <div class="wf-label mod-large">
# 			Fri, September 16, 2022
# 					</div>
# <div class="wf-card" style="margin-bottom: 30px;">
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple mod-first" href="/130690/funplus-phoenix-vs-drx-valorant-champions-2022-lr3">
# <div class="match-item-time">
# 													10:15 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-eu"></span>
# 											FunPlus Phoenix										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					0																			</div>
# </div>
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-kr"></span>
# 											DRX										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">2d 1h</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Lower Round 3							</div>
# 							Playoffs											</div>
# </a>
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple" href="/130684/loud-vs-optic-gaming-valorant-champions-2022-ubf">
# <div class="match-item-time">
# 													7:45 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-br"></span>
# 											LOUD										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-us"></span>
# 											OpTic Gaming										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					0																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">2d 3h</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Upper Final							</div>
# 							Playoffs											</div>
# </a>
# </div>
# <div class="wf-label mod-large">
# 			Tue, September 13, 2022
# 					</div>
# <div class="wf-card" style="margin-bottom: 30px;">
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple mod-first" href="/130688/xset-vs-funplus-phoenix-valorant-champions-2022-lr2">
# <div class="match-item-time">
# 													11:40 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-us"></span>
# 											XSET										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					1																			</div>
# </div>
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-eu"></span>
# 											FunPlus Phoenix										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">4d 23h</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Lower Round 2							</div>
# 							Playoffs											</div>
# </a>
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple" href="/130689/drx-vs-fnatic-valorant-champions-2022-lr2">
# <div class="match-item-time">
# 													7:30 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-kr"></span>
# 											DRX										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-eu"></span>
# 											FNATIC										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					1																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">5d 3h</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Lower Round 2							</div>
# 							Playoffs											</div>
# </a>
# </div>
# <div class="wf-label mod-large">
# 			Mon, September 12, 2022
# 					</div>
# <div class="wf-card" style="margin-bottom: 30px;">
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple mod-first" href="/130683/optic-gaming-vs-xset-valorant-champions-2022-ubsf">
# <div class="match-item-time">
# 													10:10 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-us"></span>
# 											OpTic Gaming										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-us"></span>
# 											XSET										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					1																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">6d 1h</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Upper Semifinals							</div>
# 							Playoffs											</div>
# </a>
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple" href="/130682/drx-vs-loud-valorant-champions-2022-ubsf">
# <div class="match-item-time">
# 													7:30 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-kr"></span>
# 											DRX										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					0																			</div>
# </div>
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-br"></span>
# 											LOUD										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">6d 3h</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Upper Semifinals							</div>
# 							Playoffs											</div>
# </a>
# </div>
# <div class="wf-label mod-large">
# 			Sun, September 11, 2022
# 					</div>
# <div class="wf-card" style="margin-bottom: 30px;">
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple mod-first" href="/130687/team-liquid-vs-fnatic-valorant-champions-2022-lr1">
# <div class="match-item-time">
# 													10:25 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-eu"></span>
# 											Team Liquid										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					0																			</div>
# </div>
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-eu"></span>
# 											FNATIC										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">1w 0d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Lower Round 1							</div>
# 							Playoffs											</div>
# </a>
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple" href="/130686/funplus-phoenix-vs-leviat-n-valorant-champions-2022-lr1">
# <div class="match-item-time">
# 													7:30 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-eu"></span>
# 											FunPlus Phoenix										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-cl"></span>
# 											Leviatán										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					0																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">1w 0d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Lower Round 1							</div>
# 							Playoffs											</div>
# </a>
# </div>
# <div class="wf-label mod-large">
# 			Sat, September 10, 2022
# 					</div>
# <div class="wf-card" style="margin-bottom: 30px;">
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple mod-first" href="/130681/xset-vs-fnatic-valorant-champions-2022-ubqf">
# <div class="match-item-time">
# 													11:20 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-us"></span>
# 											XSET										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-eu"></span>
# 											FNATIC										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					0																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">1w 0d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Upper Quarterfinals							</div>
# 							Playoffs											</div>
# </a>
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple" href="/130680/optic-gaming-vs-team-liquid-valorant-champions-2022-ubqf">
# <div class="match-item-time">
# 													7:30 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-us"></span>
# 											OpTic Gaming										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-eu"></span>
# 											Team Liquid										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					1																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">1w 1d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Upper Quarterfinals							</div>
# 							Playoffs											</div>
# </a>
# </div>
# <div class="wf-label mod-large">
# 			Fri, September 9, 2022
# 					</div>
# <div class="wf-card" style="margin-bottom: 30px;">
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple mod-first" href="/130678/drx-vs-funplus-phoenix-valorant-champions-2022-ubqf">
# <div class="match-item-time">
# 													10:30 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-kr"></span>
# 											DRX										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-eu"></span>
# 											FunPlus Phoenix										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					0																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">1w 2d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Upper Quarterfinals							</div>
# 							Playoffs											</div>
# </a>
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple" href="/130679/leviat-n-vs-loud-valorant-champions-2022-ubqf">
# <div class="match-item-time">
# 													7:30 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-cl"></span>
# 											Leviatán										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					0																			</div>
# </div>
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-br"></span>
# 											LOUD										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">1w 2d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Upper Quarterfinals							</div>
# 							Playoffs											</div>
# </a>
# </div>
# <div class="wf-label mod-large">
# 			Thu, September 8, 2022
# 					</div>
# <div class="wf-card" style="margin-bottom: 30px;">
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple mod-first" href="/130636/100-thieves-vs-fnatic-valorant-champions-2022-group-stage-decider-d">
# <div class="match-item-time">
# 													10:05 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-us"></span>
# 											100 Thieves										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					0																			</div>
# </div>
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-eu"></span>
# 											FNATIC										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">1w 3d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Decider (D)							</div>
# 							Group Stage											</div>
# </a>
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple" href="/130631/funplus-phoenix-vs-kr-esports-valorant-champions-2022-group-stage-decider-c">
# <div class="match-item-time">
# 													7:30 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-eu"></span>
# 											FunPlus Phoenix										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-cl"></span>
# 											KRÜ Esports										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					0																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">1w 3d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Decider (C)							</div>
# 							Group Stage											</div>
# </a>
# </div>
# <div class="wf-label mod-large">
# 			Wed, September 7, 2022
# 					</div>
# <div class="wf-card" style="margin-bottom: 30px;">
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple mod-first" href="/130626/loud-vs-zeta-division-valorant-champions-2022-group-stage-decider-b">
# <div class="match-item-time">
# 													11:30 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-br"></span>
# 											LOUD										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-jp"></span>
# 											ZETA DIVISION										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					0																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">1w 3d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Decider (B)							</div>
# 							Group Stage											</div>
# </a>
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple" href="/130621/paper-rex-vs-team-liquid-valorant-champions-2022-group-stage-decider-a">
# <div class="match-item-time">
# 													7:30 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-sg"></span>
# 											Paper Rex										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					1																			</div>
# </div>
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-eu"></span>
# 											Team Liquid										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">1w 4d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Decider (A)							</div>
# 							Group Stage											</div>
# </a>
# </div>
# <div class="wf-label mod-large">
# 			Tue, September 6, 2022
# 					</div>
# <div class="wf-card" style="margin-bottom: 30px;">
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple mod-first" href="/130629/funplus-phoenix-vs-xset-valorant-champions-2022-group-stage-winners-c">
# <div class="match-item-time">
# 													12:40 AM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-eu"></span>
# 											FunPlus Phoenix										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					1																			</div>
# </div>
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-us"></span>
# 											XSET										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">1w 5d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Winner's (C)							</div>
# 							Group Stage											</div>
# </a>
# </div>
# <div class="wf-label mod-large">
# 			Mon, September 5, 2022
# 					</div>
# <div class="wf-card" style="margin-bottom: 30px;">
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple mod-first" href="/130635/furia-vs-fnatic-valorant-champions-2022-group-stage-elim-d">
# <div class="match-item-time">
# 													8:50 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-br"></span>
# 											FURIA										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					1																			</div>
# </div>
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-eu"></span>
# 											FNATIC										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">1w 6d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Elimination (D)							</div>
# 							Group Stage											</div>
# </a>
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple" href="/130630/kr-esports-vs-xerxia-esports-valorant-champions-2022-group-stage-elim-c">
# <div class="match-item-time">
# 													5:30 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-cl"></span>
# 											KRÜ Esports										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-th"></span>
# 											XERXIA Esports										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# ...
# <div class="match-item-time">
# 													12:30 AM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-us"></span>
# 											OpTic Gaming										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-br"></span>
# 											LOUD										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					1																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">2w 1d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Winner's (B)							</div>
# 							Group Stage											</div>
# </a>
# </div>
# <div class="wf-label mod-large">
# 			Fri, September 2, 2022
# 					</div>
# <div class="wf-card" style="margin-bottom: 30px;">
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple mod-first" href="/130633/fnatic-vs-100-thieves-valorant-champions-2022-group-stage-opening-d">
# <div class="match-item-time">
# 													8:40 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-eu"></span>
# 											FNATIC										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					1																			</div>
# </div>
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-us"></span>
# 											100 Thieves										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">2w 2d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Opening (D)							</div>
# 							Group Stage											</div>
# </a>
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple" href="/130632/drx-vs-furia-valorant-champions-2022-group-stage-opening-d">
# <div class="match-item-time">
# 													5:30 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-kr"></span>
# 											DRX										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-br"></span>
# 											FURIA										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					0																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">2w 2d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Opening (D)							</div>
# 							Group Stage											</div>
# </a>
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple" href="/130619/paper-rex-vs-leviat-n-valorant-champions-2022-group-stage-winners-a">
# <div class="match-item-time">
# 													12:05 AM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-sg"></span>
# 											Paper Rex										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					0																			</div>
# </div>
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-cl"></span>
# 											Leviatán										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">2w 2d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Winner's (A)							</div>
# 							Group Stage											</div>
# </a>
# </div>
# <div class="wf-label mod-large">
# 			Thu, September 1, 2022
# 					</div>
# <div class="wf-card" style="margin-bottom: 30px;">
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple mod-first" href="/130622/optic-gaming-vs-boom-esports-valorant-champions-2022-group-stage-opening-b">
# <div class="match-item-time">
# 													8:15 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-us"></span>
# 											OpTic Gaming										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-id"></span>
# 											BOOM Esports										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					1																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">2w 3d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Opening (B)							</div>
# 							Group Stage											</div>
# </a>
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple" href="/130623/zeta-division-vs-loud-valorant-champions-2022-group-stage-opening-b">
# <div class="match-item-time">
# 													5:30 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-jp"></span>
# 											ZETA DIVISION										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					0																			</div>
# </div>
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-br"></span>
# 											LOUD										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">2w 3d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Opening (B)							</div>
# 							Group Stage											</div>
# </a>
# </div>
# <div class="wf-label mod-large">
# 			Wed, August 31, 2022
# 					</div>
# <div class="wf-card" style="margin-bottom: 30px;">
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple mod-first" href="/130618/leviat-n-vs-team-liquid-valorant-champions-2022-group-stage-opening-a">
# <div class="match-item-time">
# 													11:05 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-cl"></span>
# 											Leviatán										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-eu"></span>
# 											Team Liquid										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					0																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">2w 4d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Opening (A)							</div>
# 							Group Stage											</div>
# </a>
# <a class="wf-module-item match-item mod-color mod-left mod-bg-after-striped_purple" href="/130617/paper-rex-vs-edward-gaming-valorant-champions-2022-group-stage-opening-a">
# <div class="match-item-time">
# 													7:30 PM											</div>
# <div class="match-item-vs">
# <div class="match-item-vs-team mod-winner">
# <div class="match-item-vs-team-name">
# <i class="js-spoiler fa fa-caret-right" style="position: absolute; left: -10px; top: 1px; color: #61b875; font-size: 11px;"></i>
# <div class="text-of">
# <span class="flag mod-sg"></span>
# 											Paper Rex										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					2																			</div>
# </div>
# <div class="match-item-vs-team">
# <div class="match-item-vs-team-name">
# <div class="text-of">
# <span class="flag mod-cn"></span>
# 											EDward Gaming										</div>
# </div>
# <div class="match-item-vs-team-score js-spoiler">
# 																					1																			</div>
# </div>
# </div>
# <div class="match-item-eta">
# <div class="ml mod-completed">
# <div class="ml-status">Completed</div>
# <div class="ml-eta mod-completed">2w 4d</div>
# </div>
# </div>
# <div class="match-item-note">
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							Stats:
# 						</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Map
# 								</div>
# <div class="wf-tag mod-big" style="background: #e05c65;">
# 									Player
# 								</div>
# </div>
# <div class="match-item-vod">
# <div class="wf-module-label">
# 							VODs:
# 						</div>
# <div class="wf-tag mod-big mod-yt">
# 								YouTube
# 							</div>
# <div class="wf-tag mod-big mod-twitch">
# 								Twitch
# 							</div>
# </div>
# <div class="match-item-event text-of">
# <div class="match-item-event-series text-of">
# 								Opening (A)							</div>
# 							Group Stage											</div>
# </a>
# </div>
# </div>
# </div>
# <div class="media-vw">
# </div>
# </div>
# <div class="footer">
# <div class="footer-inner">
# <div class="header-div mod-first"></div>
# <a class="contact" href="mailto:community@VLR.gg">Contact</a>
# <div class="sdot">•</div>
# <a class="privacy" href="/privacy">Privacy</a>
# <div class="sdot">•</div>
# <a href="/user/view/desktop">
# 					Switch to Desktop
# 				</a>
# <div class="find-txt">
# 				Find us on:
# 			</div>
# <a class="social mod-twitter" href="https://twitter.com/vlrdotgg" target="_blank">
# <i class="fa fa-twitter mod-twitter"></i>Twitter
# 				</a>
# <a class="social mod-discord" href="https://discord.com/invite/VLR" target="_blank">
# <img class="mod-discord" src="/img/icons/social/discord.svg"/>Discord
# 				</a>
# <a class="social" href="https://vk.com/vlrdotgg" target="_blank">
# <i class="fa fa-vk mod-vk" style="margin-right: 3px;"></i>VK
# 				</a>
# <div class="header-div mod-last"></div>
# </div>
# </div> <script src="/js/common/vendor/jquery.min.js"></script>
# <script src="/js/common/main.min.js?v=67"></script>
# <script src="/js/common/vendor/jquery.dragscroll.min.js"></script>
# <script src="/js/common/event.js?v=10"></script>
# <a id="bottom"></a>
# </body>
# </html>

# %%
eventSoup.title.text
# Out:
# '\n\t\t\tValorant Champions 2022: Schedule and Results | Valorant Event | VLR.gg\t\t'

# %%
def MatchExactClassName(tag):
    return tag.has_attr('class') and tag['class'] == ['wf-card']

# %%
daysMatches = eventSoup.body.find_all(MatchExactClassName)

# %%
matchId = 0

for dayMatches in daysMatches:
    matchesOfTheDay = dayMatches.find_all('a')
    for match in matchesOfTheDay:
        matchId = matchId + 1
        print("Match: " + str(matchId))
        matchSoup = BeautifulSoup(requests.get(baseUrl + match['href']).text)
        
        fileName = str(matchId) + " " + match['href'].split("/")[-1] + ' '.join(matchSoup.find_all("div", {"class": "match-header-date"})[0].text.split())
        
        matchData = MatchData()
        matchData.Date = ' '.join(matchSoup.find_all("div", {"class": "match-header-date"})[0].text.split())
        matchData.Team1 = ' '.join(matchSoup.find_all("div", {"class": "wf-title-med"})[0].text.split())
        matchData.Team2 = ' '.join(matchSoup.find_all("div", {"class": "wf-title-med"})[1].text.split())
        matchData.Team1Score = int(' '.join(matchSoup.find_all("div", {"class": "js-spoiler"})[0].find_all("span")[0].text.split()))
        matchData.Team2Score = int(' '.join(matchSoup.find_all("div", {"class": "js-spoiler"})[0].find_all("span")[-1].text.split()))
        
        ############# Head to Head Matches section
        h2hSection = matchSoup.find_all("a", {"class": "mod-h2h"})
        
        for h2h in h2hSection:
            h2hData = HeadToHeadData()
            
            h2hData.Team1Score = int(h2h.find_all("span", {"class": "rf"})[0].text)
            h2hData.Team2Score = int(h2h.find_all("span", {"class": "ra"})[0].text)
            h2hData.Date = ' '.join(h2h.find_all("div", {"class": "match-h2h-matches-date"})[0].text.split())
            
            matchData.ListOfHeadToHead.append(h2hData)
        
        ############# Match History Section
        matchHistorySections = matchSoup.find_all("div", {"class": "match-histories"})
        
        #Team1     matchHistorySections[0]
        for matchHistory in matchHistorySections[0].find_all("a", {"class": "match-histories-item"}):
            pastMatchesData1 = PastMatchesData()
            
            pastMatchesData1.OurTeamScore = int(matchHistory.find_all("span", {"class": "rf"})[0].text)
            pastMatchesData1.Team2Score = int(matchHistory.find_all("span", {"class": "ra"})[0].text)
            pastMatchesData1.Team2 = matchHistory.find_all("span", {"class": "match-histories-item-opponent-name"})[0].text
            pastMatchesData1.Date = ' '.join(matchHistory.find_all("div", {"class": "match-histories-item-date"})[0].text.split())
            
            matchData.Team1PastMatches.append(pastMatchesData1)
            
        #Team2     matchHistorySections[1]
        for matchHistory in matchHistorySections[1].find_all("a", {"class": "match-histories-item"}):
            pastMatchesData2 = PastMatchesData()
            
            pastMatchesData2.OurTeamScore = int(matchHistory.find_all("span", {"class": "rf"})[0].text)
            pastMatchesData2.Team2Score = int(matchHistory.find_all("span", {"class": "ra"})[0].text)
            pastMatchesData2.Team2 = matchHistory.find_all("span", {"class": "match-histories-item-opponent-name"})[0].text
            pastMatchesData2.Date = ' '.join(matchHistory.find_all("div", {"class": "match-histories-item-date"})[0].text.split())
            
            matchData.Team2PastMatches.append(pastMatchesData2)
            
        
        ############# Map Data
        mapsSoup = matchSoup.find_all("div", {"class": "vm-stats-game"})
        
        mapNumber = 1
        for mapSoup in mapsSoup:
            mapData = MapData()
            
            ## Map specific details
            if(mapSoup['data-game-id'] != 'all'):
                mapData.MapNumber = mapNumber
                mapData.MapName = mapSoup.find_all("div", {"class": "map"})[0].span.text.split()[0]
                mapData.Team1Score = int(mapSoup.find_all("div", {"class": "score"})[0].text)
                mapData.Team2Score = int(mapSoup.find_all("div", {"class": "score"})[1].text)
                mapData.Team1Attack = int(mapSoup.find_all("span", {"class": "mod-t"})[0].text)
                mapData.Team2Attack = int(mapSoup.find_all("span", {"class": "mod-t"})[1].text)
                
                if(len(mapSoup.find_all("div", {"class": "map"})[0].find_all("span")) == 1):
                    mapData.Pick = "Decider"
                else:
                    mapData.Pick = "Team " + mapSoup.find_all("div", {"class": "map"})[0].span()[0]['class'][1][-1]
                
                scoreSoupList = mapSoup.find_all("div", {"class": "rnd-currscore"})
                for scoreSoup in scoreSoupList:
                    if(len(scoreSoup.text.split()) > 0):
                        mapData.ListOfRounds.append(scoreSoup.text.split()[0].split("-"))

                mapNumber = mapNumber + 1
            else:
                mapData.MapName = 'all'
                mapData.MapNumber = 0
            
            ## Player stats
            
            playerDataSoup = mapSoup.find_all("table", {"class": "wf-table-inset mod-overview"})
                    
            # Team1    playerDataSoup[0]
            team1PlayersSoup = playerDataSoup[0].tbody.find_all("tr")
            for playerSoup in team1PlayersSoup:
                playerData = PlayerData()
                
                playerData.Name = playerSoup.find_all("div", {"class": "text-of"})[0].text.split()[0]
                playerData.Team = playerSoup.find_all("div", {"class": "ge-text-light"})[0].text.split()[0]
                
                statsList = playerSoup.find_all("td", {"class": "mod-stat"})
                
                playerData.ACS = [int(statsList[0].find_all("span", {"class": "mod-both"})[0].text), int(statsList[0].find_all("span", {"class": "mod-t"})[0].text), int(statsList[0].find_all("span", {"class": "mod-ct"})[0].text)]
                playerData.Kills = [int(statsList[1].find_all("span", {"class": "mod-both"})[0].text), int(statsList[1].find_all("span", {"class": "mod-t"})[0].text), int(statsList[1].find_all("span", {"class": "mod-ct"})[0].text)]
                playerData.Deaths = [int(statsList[2].find_all("span", {"class": "mod-both"})[0].text), int(statsList[2].find_all("span", {"class": "mod-t"})[0].text), int(statsList[2].find_all("span", {"class": "mod-ct"})[0].text)]
                playerData.Assists = [int(statsList[3].find_all("span", {"class": "mod-both"})[0].text), int(statsList[3].find_all("span", {"class": "mod-t"})[0].text), int(statsList[3].find_all("span", {"class": "mod-ct"})[0].text)]
                playerData.KAST = [statsList[5].find_all("span", {"class": "mod-both"})[0].text, statsList[5].find_all("span", {"class": "mod-t"})[0].text, statsList[5].find_all("span", {"class": "mod-ct"})[0].text]
                playerData.ADR = [int(statsList[6].find_all("span", {"class": "mod-both"})[0].text), int(statsList[6].find_all("span", {"class": "mod-t"})[0].text), int(statsList[6].find_all("span", {"class": "mod-ct"})[0].text)]
                playerData.HeadshotPercent = [statsList[7].find_all("span", {"class": "mod-both"})[0].text, statsList[7].find_all("span", {"class": "mod-t"})[0].text, statsList[7].find_all("span", {"class": "mod-ct"})[0].text]
                playerData.FirstKills = [int(statsList[8].find_all("span", {"class": "mod-both"})[0].text), int(statsList[8].find_all("span", {"class": "mod-t"})[0].text), int(statsList[8].find_all("span", {"class": "mod-ct"})[0].text)]
                playerData.FirstDeaths = [int(statsList[9].find_all("span", {"class": "mod-both"})[0].text), int(statsList[9].find_all("span", {"class": "mod-t"})[0].text), int(statsList[9].find_all("span", {"class": "mod-ct"})[0].text)]
                
                mapData.ListOfPlayerDataTeam1.append(playerData)
            
            # Team2    playerDataSoup[1]
            team2PlayersSoup = playerDataSoup[1].tbody.find_all("tr")
            for playerSoup in team2PlayersSoup:
                playerData = PlayerData()
                
                playerData.Name = playerSoup.find_all("div", {"class": "text-of"})[0].text.split()[0]
                playerData.Team = playerSoup.find_all("div", {"class": "ge-text-light"})[0].text.split()[0]
                
                statsList = playerSoup.find_all("td", {"class": "mod-stat"})
                
                playerData.ACS = [int(statsList[0].find_all("span", {"class": "mod-both"})[0].text), int(statsList[0].find_all("span", {"class": "mod-t"})[0].text), int(statsList[0].find_all("span", {"class": "mod-ct"})[0].text)]
                playerData.Kills = [int(statsList[1].find_all("span", {"class": "mod-both"})[0].text), int(statsList[1].find_all("span", {"class": "mod-t"})[0].text), int(statsList[1].find_all("span", {"class": "mod-ct"})[0].text)]
                playerData.Deaths = [int(statsList[2].find_all("span", {"class": "mod-both"})[0].text), int(statsList[2].find_all("span", {"class": "mod-t"})[0].text), int(statsList[2].find_all("span", {"class": "mod-ct"})[0].text)]
                playerData.Assists = [int(statsList[3].find_all("span", {"class": "mod-both"})[0].text), int(statsList[3].find_all("span", {"class": "mod-t"})[0].text), int(statsList[3].find_all("span", {"class": "mod-ct"})[0].text)]
                playerData.KAST = [statsList[5].find_all("span", {"class": "mod-both"})[0].text, statsList[5].find_all("span", {"class": "mod-t"})[0].text, statsList[5].find_all("span", {"class": "mod-ct"})[0].text]
                playerData.ADR = [int(statsList[6].find_all("span", {"class": "mod-both"})[0].text), int(statsList[6].find_all("span", {"class": "mod-t"})[0].text), int(statsList[6].find_all("span", {"class": "mod-ct"})[0].text)]
                playerData.HeadshotPercent = [statsList[7].find_all("span", {"class": "mod-both"})[0].text, statsList[7].find_all("span", {"class": "mod-t"})[0].text, statsList[7].find_all("span", {"class": "mod-ct"})[0].text]
                playerData.FirstKills = [int(statsList[8].find_all("span", {"class": "mod-both"})[0].text), int(statsList[8].find_all("span", {"class": "mod-t"})[0].text), int(statsList[8].find_all("span", {"class": "mod-ct"})[0].text)]
                playerData.FirstDeaths = [int(statsList[9].find_all("span", {"class": "mod-both"})[0].text), int(statsList[9].find_all("span", {"class": "mod-t"})[0].text), int(statsList[9].find_all("span", {"class": "mod-ct"})[0].text)]
                
                mapData.ListOfPlayerDataTeam2.append(playerData)
            
            
            matchData.ListOfMapData.append(mapData)
            
            
        #json_object = json.dumps(EmployeeEncoder().encode(matchData))
        json_object = json.dumps(matchData, indent=4, cls=EmployeeEncoder)
        with open(fileName+".json", "w") as outfile:
            outfile.write(json_object)
# Out:
# Match: 1
# Match: 2
# Match: 3
# Match: 4
# Match: 5
# Match: 6
# Match: 7
# Match: 8
# Match: 9
# Match: 10
# Match: 11
# Match: 12
# Match: 13
# Match: 14
# Match: 15
# Match: 16
# Match: 17
# Match: 18
# Match: 19
# Match: 20
# Match: 21
# Match: 22
# Match: 23
# Match: 24
# Match: 25
# Match: 26
# Match: 27
# Match: 28
# Match: 29
# Match: 30
# Match: 31
# Match: 32
# Match: 33

# %%
"""print("Decode JSON formatted Data")
employeeJSON = json.loads(employeeJSONData)
print(employeeJSON)"""
